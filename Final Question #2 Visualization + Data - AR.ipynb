# %%
import pandas as pd

# Load the data
adoption_data = pd.read_csv("Desktop/adoption.csv")

adoption_data.head()
# Out:
#    Animal_ID type                 breed     location           color    size  \
# 0          0  Cat   Domestic Short Hair     Woodmere  Orange & White  Medium
# 1          1  Cat   Domestic Short Hair     New York    Gray & White   Small
# 2          2  Cat   Domestic Short Hair  Trexlertown             NaN  Medium
# 3          3  Cat  Domestic Medium Hair    Pittstown           White   Large
# 4          4  Cat   Domestic Short Hair  Mount Holly             NaN   Small
#
#                 date_posted           name     status  gender
# 0  2024-02-09T01:22:49+0000             CJ  adoptable    Male
# 1  2024-02-09T01:15:51+0000  Ron and Harry  adoptable  Female
# 2  2024-02-09T01:13:49+0000           Luna  adoptable  Female
# 3  2024-02-09T01:08:33+0000     Sweet pea   adoptable    Male
# 4  2024-02-09T01:06:28+0000       Robinson  adoptable  Female

# %%
# Create a new dataframe featuring DOG data only from specified cities
cities = ["New York", "Los Angeles", "Chicago", "Houston", "Phoenix", "Mesa", "Schaumburg", "Pearland", "Yonkers", "Mission Viejo"]

# Filter for dogs and the specified cities
dog_data_cities = adoption_data[(adoption_data['type'] == 'Dog') & (adoption_data['location'].isin(cities))]

dog_data_cities
# Out:
#        Animal_ID type                breed  location  \
# 11741      11741  Dog        Border Collie  New York
# 11746      11746  Dog               Beagle  New York
# 11753      11753  Dog       French Bulldog  New York
# 11775      11775  Dog     Pit Bull Terrier  New York
# 11776      11776  Dog     Pit Bull Terrier  New York
# ...          ...  ...                  ...       ...
# 61988      61988  Dog     Brussels Griffon   Phoenix
# 61989      61989  Dog            Chihuahua   Phoenix
# 61993      61993  Dog   Labrador Retriever   Phoenix
# 62002      62002  Dog  German Shepherd Dog   Phoenix
# 62008      62008  Dog  Australian Shepherd   Phoenix
#
#                                   color    size               date_posted  \
# 11741  Tricolor (Brown, Black, & White)  Medium  2024-02-09T01:15:51+0000
# 11746                               NaN  Medium  2024-02-09T01:00:01+0000
# 11753                               NaN  Medium  2024-02-09T00:14:29+0000
# ...

# %%
# Data for New York
new_york_data = dog_data_cities[dog_data_cities['location'] == 'New York']
new_york_size_count = new_york_data['size'].value_counts()

# Plot pie chart for New York
plt.figure(figsize=(8, 8))
plt.pie(new_york_size_count, labels=new_york_size_count.index, autopct='%1.1f%%', startangle=140)
plt.title('New York')
plt.show()

# %%
# Data for Los Angeles
los_angeles_data = dog_data_cities[dog_data_cities['location'] == 'Los Angeles']
los_angeles_size_count = los_angeles_data['size'].value_counts()

# Plot pie chart for Los Angeles
plt.figure(figsize=(8, 8))
plt.pie(los_angeles_size_count, labels=los_angeles_size_count.index, autopct='%1.1f%%', startangle=140)
plt.title('Los Angeles')
plt.show()

# %%
# Data for Chicago
chicago_data = dog_data_cities[dog_data_cities['location'] == 'Chicago']
chicago_size_count = chicago_data['size'].value_counts()

# Plot pie chart for Chicago
plt.figure(figsize=(8, 8))
plt.pie(chicago_size_count, labels=chicago_size_count.index, autopct='%1.1f%%', startangle=140)
plt.title('Chicago')
plt.show()

# %%
# Data for Houston
houston_data = dog_data_cities[dog_data_cities['location'] == 'Houston']
houston_size_count = houston_data['size'].value_counts()

# Plot pie chart for Houston
plt.figure(figsize=(8, 8))
plt.pie(houston_size_count, labels=houston_size_count.index, autopct='%1.1f%%', startangle=140)
plt.title('Houston')
plt.show()

# %%
# Data for Phoenix
phoenix_data = dog_data_cities[dog_data_cities['location'] == 'Phoenix']
phoenix_size_count = phoenix_data['size'].value_counts()

# Plot pie chart for Phoenix
plt.figure(figsize=(8, 8))
plt.pie(phoenix_size_count, labels=phoenix_size_count.index, autopct='%1.1f%%', startangle=140)
plt.title('Phoenix')
plt.show()

# %%
# Data for Mesa
mesa_data = dog_data_cities[dog_data_cities['location'] == 'Mesa']
mesa_size_count = mesa_data['size'].value_counts()

# Plot pie chart for Mesa
plt.figure(figsize=(8, 8))
plt.pie(mesa_size_count, labels=mesa_size_count.index, autopct='%1.1f%%', startangle=140)
plt.title('Mesa')
plt.show()

# %%
# Data for Schaumburg
schaumburg_data = dog_data_cities[dog_data_cities['location'] == 'Schaumburg']
schaumburg_size_count = schaumburg_data['size'].value_counts()

# Plot pie chart for Schaumburg
plt.figure(figsize=(8, 8))
plt.pie(schaumburg_size_count, labels=schaumburg_size_count.index, autopct='%1.1f%%', startangle=140)
plt.title('Schaumburg')
plt.show()

# %%
# Data for Pearland
pearland_data = dog_data_cities[dog_data_cities['location'] == 'Pearland']
pearland_size_count = pearland_data['size'].value_counts()

# Plot pie chart for Pearland
plt.figure(figsize=(8, 8))
plt.pie(pearland_size_count, labels=pearland_size_count.index, autopct='%1.1f%%', startangle=140)
plt.title('Pearland')
plt.show()

# %%
# Data for Yonkers
yonkers_data = dog_data_cities[dog_data_cities['location'] == 'Yonkers']
yonkers_size_count = yonkers_data['size'].value_counts()

# Plot pie chart for Yonkers
plt.figure(figsize=(8, 8))
plt.pie(yonkers_size_count, labels=yonkers_size_count.index, autopct='%1.1f%%', startangle=140)
plt.title('Yonkers')
plt.show()

# %%
# Data for Mission Viejo
mission_viejo_data = dog_data_cities[dog_data_cities['location'] == 'Mission Viejo']
mission_viejo_size_count = mission_viejo_data['size'].value_counts()

# Plot pie chart for Mission Viejo
plt.figure(figsize=(8, 8))
plt.pie(mission_viejo_size_count, labels=mission_viejo_size_count.index, autopct='%1.1f%%', startangle=140)
plt.title('Mission Viejo')
plt.show()

# %%
# Count the total number of dogs in each specified city
total_dogs_per_city = dog_data_cities.groupby('location').size().reset_index(name='Total Dogs')

# Display the result
print(total_dogs_per_city)
# Out:
#         location  Total Dogs
# 0        Chicago         384
# 1        Houston        2053
# 2    Los Angeles        1624
# 3           Mesa         404
# 4  Mission Viejo          52
# 5       New York         798
# 6       Pearland          95
# 7        Phoenix        1009
# 8     Schaumburg          24
# 9        Yonkers          45

# %%
# Filter for large dogs in the specified cities
large_dog_data_cities = dog_data_cities[dog_data_cities['size'] == 'Large']

# Count the total number of large dogs in each specified city
total_large_dogs_per_city = large_dog_data_cities.groupby('location').size().reset_index(name='Total Large Dogs')

# Display the result
print(total_large_dogs_per_city)
# Out:
#         location  Total Large Dogs
# 0        Chicago               137
# 1        Houston               601
# 2    Los Angeles               867
# 3           Mesa               334
# 4  Mission Viejo                17
# 5       New York               132
# 6       Pearland                29
# 7        Phoenix               420
# 8     Schaumburg                 6
# 9        Yonkers                17

# %%
import numpy as np
from statsmodels.stats.proportion import proportions_ztest

cities_data = {
    "New York": (132, 798),
    "Los Angeles": (867, 1624),
    "Chicago": (137, 384),
    "Houston": (601, 2053),
    "Phoenix": (420, 1009),
}

suburb_data = {
    "Yonkers": (17, 45),
    "Mission Viejo": (17, 52),
    "Schaumburg": (6, 24),
    "Pearland": (29, 95),
    "Mesa": (334, 404)
}

# Function to run the p-test
def run_p_test(city_data, suburb_data):
    count = np.array([city_data[0], suburb_data[0]])
    nobs = np.array([city_data[1], suburb_data[1]])
    stat, pval = proportions_ztest(count, nobs)
    return stat, pval

# Running the tests
comparisons = [("New York", "Yonkers"), ("Los Angeles", "Mission Viejo"), 
               ("Chicago", "Schaumburg"), ("Houston", "Pearland"), 
               ("Phoenix", "Mesa")]

for city, suburb in comparisons:
    stat, pval = run_p_test(cities_data[city], suburb_data[suburb]) 
    print(f"{city} vs. {suburb}: p-value = {pval:.4f}")
# Out:
# New York vs. Yonkers: p-value = 0.0003
# Los Angeles vs. Mission Viejo: p-value = 0.0033
# Chicago vs. Schaumburg: p-value = 0.2875
# Houston vs. Pearland: p-value = 0.7933
# Phoenix vs. Mesa: p-value = 0.0000

# %%
# Running the tests and calculating the average of all p-values
p_values = []

for city, suburb in comparisons:
    _, pval = run_p_test(cities_data[city], suburb_data[suburb]) 
    p_values.append(pval)

# Calculating the average of the p-values
average_p_value = np.mean(p_values)

average_p_value
# Out:
# 0.21686782127988408

# %%
import matplotlib.pyplot as plt

# Define a purplescale color palette
colors = ['#6a0dad', '#9b30ff', '#d8bfd8', '#e6e6fa']  # Shades of purple

# Unique locations in the DataFrame
locations = dog_data_cities['location'].unique()

# Loop through each location and plot pie chart
for location in locations:
    # Filter data for the current location
    location_data = dog_data_cities[dog_data_cities['location'] == location]
    location_size_count = location_data['size'].value_counts()

    # Plot pie chart for the current location with purplescale colors
    plt.figure(figsize=(8, 8))
    plt.pie(location_size_count, labels=location_size_count.index, autopct='%1.1f%%', startangle=140, colors=colors)
    plt.title(f'{location} Adoptable Dogs By Size', fontsize=14, fontweight='bold')  # Bold and readable title
    plt.show()
